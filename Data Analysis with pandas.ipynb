# %% [markdown]
# # Data Analysis with Pandas

# %%
import numpy as np
import pandas as pd

# %%
order = pd.read_table('http://bit.ly/chiporders')

# %%
 order
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
movie = pd.read_table('http://bit.ly/movieusers')
movie.head(5)
# Out:
#    1|24|M|technician|85711
# 0       2|53|F|other|94043
# 1      3|23|M|writer|32067
# 2  4|24|M|technician|43537
# 3       5|33|F|other|15213
# 4   6|42|M|executive|98101

# %%
movie = pd.read_table('http://bit.ly/movieusers',sep = '|',header = None)
movie.head(5)  # tab separated value
# Out:
#    0   1  2           3      4
# 0  1  24  M  technician  85711
# 1  2  53  F       other  94043
# 2  3  23  M      writer  32067
# 3  4  24  M  technician  43537
# 4  5  33  F       other  15213

# %%
user_cols = ['user_id','age','gender','occupation','pincode']
movie = pd.read_table('http://bit.ly/movieusers',sep = '|',header = None, names = user_cols)
movie.head(5)
# Out:
#    user_id  age gender  occupation pincode
# 0        1   24      M  technician   85711
# 1        2   53      F       other   94043
# 2        3   23      M      writer   32067
# 3        4   24      M  technician   43537
# 4        5   33      F       other   15213

# %%
pd.read_table('http://bit.ly/uforeports', sep = ',')
ufo = pd.read_csv('http://bit.ly/uforeports')  # csv - comma separated value
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Selecting A Series

# %%
ufo['City']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
ufo.City.head() # after . we can press sift+tab to check all the attrbutes and methods
# Out:
# 0                  Ithaca
# 1             Willingboro
# 2                 Holyoke
# 3                 Abilene
# 4    New York Worlds Fair
# Name: City, dtype: object

# %%
type(ufo.City)
# Out:
# pandas.core.series.Series

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
'ab'+'cd'
# Out:
# 'abcd'

# %%
'minu'+ ' '+ 'munna'
# Out:
# 'minu munna'

# %%
ufo.City+ ' '+ ufo.State
# Out:
# 0                      Ithaca NY
# 1                 Willingboro NJ
# 2                     Holyoke CO
# 3                     Abilene KS
# 4        New York Worlds Fair NY
#                   ...
# 18236              Grant Park IL
# 18237             Spirit Lake IA
# 18238             Eagle River WI
# 18239             Eagle River WI
# 18240                    Ybor FL
# Length: 18241, dtype: object

# %% [markdown]
# ### Why do some pandas command ends with parantheses and others don't

# %%
ratings = pd.read_csv('http://bit.ly/imdbratings')
ratings.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
ratings.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
ratings.shape
# Out:
# (979, 6)

# %%
ratings.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
type(ratings)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# as Dataframe or Series are objects they have methods with parantheses and attributes without parantheses.
# e.g Minu is a human object and it has eat(), talk() as method and height,age as attributes.
#   Minu.eat()   Minu.age

# %%
ratings.describe(include = ['object']) # just press sift+tab inside the parantheses to check the arguments
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %% [markdown]
# ### Rename columns in pandas Dataframe

# %%
ufo.head(2)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.rename(columns = {'Colors Reported':'Colors_Reported','Shape Reported':'Shape_Reported'},inplace = True)

# %%
ufo.head(2)
# Out:
#           City Colors_Reported Shape_Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
use_cols = ['City', 'Colors Reported', 'Shape Reported', 'State', 'Time']
ufo.columns = use_cols
ufo.head(2)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
ufos = pd.read_csv('http://bit.ly/uforeports',header = 0)

# %%
ufos.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufoo = pd.read_csv('http://bit.ly/uforeports',usecols = ['City','State'], nrows= 5)
ufoo
# Out:
#                    City State
# 0                Ithaca    NY
# 1           Willingboro    NJ
# 2               Holyoke    CO
# 3               Abilene    KS
# 4  New York Worlds Fair    NY

# %%
ufos.columns = ufos.columns.str.replace(' ','_')

# %%
ufos.head(3)
# Out:
#           City Colors_Reported Shape_Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# ### Remove columns from pandas Dataframe

# %%
ufos.drop('Colors_Reported',axis =1)
# Out:
#                        City Shape_Reported State              Time
# 0                    Ithaca       TRIANGLE    NY    6/1/1930 22:00
# 1               Willingboro          OTHER    NJ   6/30/1930 20:00
# 2                   Holyoke           OVAL    CO   2/15/1931 14:00
# 3                   Abilene           DISK    KS    6/1/1931 13:00
# 4      New York Worlds Fair          LIGHT    NY   4/18/1933 19:00
# ...                     ...            ...   ...               ...
# 18236            Grant Park       TRIANGLE    IL  12/31/2000 23:00
# 18237           Spirit Lake           DISK    IA  12/31/2000 23:00
# 18238           Eagle River            NaN    WI  12/31/2000 23:45
# 18239           Eagle River          LIGHT    WI  12/31/2000 23:45
# 18240                  Ybor           OVAL    FL  12/31/2000 23:59
#
# [18241 rows x 4 columns]

# %%
ufos.drop(0,axis=0).head() # axis= 0 for rows
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
# 5           Valley City             NaN           DISK    ND  9/15/1934 15:30

# %%
ufos.drop(['City','Colors_Reported'],axis =1).head()
# Out:
#   Shape_Reported State             Time
# 0       TRIANGLE    NY   6/1/1930 22:00
# 1          OTHER    NJ  6/30/1930 20:00
# 2           OVAL    CO  2/15/1931 14:00
# 3           DISK    KS   6/1/1931 13:00
# 4          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# ### Sort pandas Dataframe and Series

# %%
ratings.head(2)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']

# %%
ratings.title.sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
ratings['title'].sort_values(ascending= False)
# Out:
# 864                    [Rec]
# 526                     Zulu
# 615               Zombieland
# 677                   Zodiac
# 955         Zero Dark Thirty
#                ...
# 110    2001: A Space Odyssey
# 698                127 Hours
# 201         12 Years a Slave
# 5               12 Angry Men
# 542     (500) Days of Summer
# Name: title, Length: 979, dtype: object

# %%
ratings.sort_values('title',ascending = False)
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 864          7.5                  [Rec]              R     Horror        78
# 526          7.8                   Zulu        UNRATED      Drama       138
# 615          7.7             Zombieland              R     Comedy        88
# 677          7.7                 Zodiac              R      Crime       157
# 955          7.4       Zero Dark Thirty              R      Drama       157
# ..           ...                    ...            ...        ...       ...
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# 698          7.6              127 Hours              R  Adventure        94
# 201          8.1       12 Years a Slave              R  Biography       134
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
#
#                                            actors_list
# ...

# %%
ratings.sort_values(['content_rating','duration']).head()
# Out:
#      star_rating                           title content_rating      genre  \
# 713          7.6                 The Jungle Book       APPROVED  Animation
# 513          7.8  Invasion of the Body Snatchers       APPROVED     Horror
# 272          8.1                     The Killing       APPROVED      Crime
# 703          7.6                         Dracula       APPROVED     Horror
# 612          7.7              A Hard Day's Night       APPROVED     Comedy
#
#      duration                                        actors_list
# 713        78  [u'Phil Harris', u'Sebastian Cabot', u'Louis P...
# 513        80  [u'Kevin McCarthy', u'Dana Wynter', u'Larry Ga...
# 272        85  [u'Sterling Hayden', u'Coleen Gray', u'Vince E...
# 703        85  [u'Bela Lugosi', u'Helen Chandler', u'David Ma...
# 612        87  [u'John Lennon', u'Paul McCartney', u'George H...

# %% [markdown]
# ### Filter rows in pandas Dataframe

# %%
ratings[ratings['star_rating']>7].head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
ratings[(ratings['star_rating']>7)&(ratings['duration']<200)].head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
# 5          8.9              12 Angry Men      NOT RATED   Drama        96
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...

# %%
ratings[ratings['genre']=='Drama']['duration']
# Out:
# 5       96
# 9      139
# 13     142
# 16     133
# 17     207
#       ...
# 958    109
# 968    162
# 970    107
# 972    112
# 973    126
# Name: duration, Length: 278, dtype: int64

# %%
ratings[ratings.genre.isin(['Drama','Crime','Action'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
ratings[ratings.duration.between(100,200)]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
order.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %% [markdown]
# ### String method

# %%
order[order.item_name.str.contains('Chips')]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 6            3         1                          Side of Chips
# 10           5         1                    Chips and Guacamole
# 14           7         1                    Chips and Guacamole
# ...        ...       ...                                    ...
# 4596      1826         1                    Chips and Guacamole
# 4600      1827         1                    Chips and Guacamole
# 4605      1828         1                    Chips and Guacamole
# 4613      1831         1                                  Chips
# 4616      1832         1                    Chips and Guacamole
#
#      choice_description item_price
# 0                   NaN     $2.39
# 3                   NaN     $2.39
# 6                   NaN     $1.69
# 10                  NaN     $4.45
# ...

# %%
order.choice_description.str.replace('[','').str.replace(']','')
# Out:
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
#                               ...
# 4617    Fresh Tomato Salsa, Rice, Black Beans, Sour Cr...
# 4618    Fresh Tomato Salsa, Rice, Sour Cream, Cheese, ...
# 4619    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# 4620       Fresh Tomato Salsa, Fajita Vegetables, Lettuce
# 4621    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# Name: choice_description, Length: 4622, dtype: object

# %%
order.choice_description.str.replace('[\[\]]','')
# Out:
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
#                               ...
# 4617    Fresh Tomato Salsa, Rice, Black Beans, Sour Cr...
# 4618    Fresh Tomato Salsa, Rice, Sour Cream, Cheese, ...
# 4619    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# 4620       Fresh Tomato Salsa, Fajita Vegetables, Lettuce
# 4621    Fresh Tomato Salsa, Fajita Vegetables, Pinto B...
# Name: choice_description, Length: 4622, dtype: object

# %% [markdown]
# ### data type change

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
type(drinks.country)
# Out:
# pandas.core.series.Series

# %%
drinks['beer_servings'] = drinks.beer_servings.astype(float)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
order.item_price = order.item_price.str.replace('$','').astype(float)

# %% [markdown]
# ### Groupby in pandas

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby(['continent','country']).beer_servings.max()
# Out:
# continent      country
# Africa         Algeria          25.0
#                Angola          217.0
#                Benin            34.0
#                Botswana        173.0
#                Burkina Faso     25.0
#                                ...
# South America  Paraguay        213.0
#                Peru            163.0
#                Suriname        128.0
#                Uruguay         115.0
#                Venezuela       333.0
# Name: beer_servings, Length: 193, dtype: float64

# %%
drinks.groupby('continent').beer_servings.agg(['min','max','count'])
# Out:
#                 min    max  count
# continent
# Africa          0.0  376.0     53
# Asia            0.0  247.0     44
# Europe          0.0  361.0     45
# North America   1.0  285.0     23
# Oceania         0.0  306.0     16
# South America  93.0  333.0     12

# %%
drinks.groupby('continent').agg({'beer_servings':'max','spirit_servings':'min'})
# Out:
#                beer_servings  spirit_servings
# continent
# Africa                 376.0                0
# Asia                   247.0                0
# Europe                 361.0                0
# North America          285.0               68
# Oceania                306.0                0
# South America          333.0               25

# %%
# %matplotlib inline

# %%
drinks.groupby('continent').beer_servings.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='continent'>

# %% [markdown]
# ### explore pandas series

# %%
ratings.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
ratings.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
ratings.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
ratings.genre.value_counts(normalize=True) # percentage
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Sci-Fi       0.005107
# Thriller     0.005107
# Film-Noir    0.003064
# Family       0.002043
# Fantasy      0.001021
# History      0.001021
# Name: genre, dtype: float64

# %%
ratings.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
ratings.genre.nunique()
# Out:
# 16

# %%
pd.crosstab(ratings.genre,ratings.content_rating)
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %% [markdown]
# ### missing value handeling

# %%
ufo.head(3)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.isna().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo[ufo.isnull()]
# Out:
#       City Colors Reported Shape Reported State Time
# 0      NaN             NaN            NaN   NaN  NaN
# 1      NaN             NaN            NaN   NaN  NaN
# 2      NaN             NaN            NaN   NaN  NaN
# 3      NaN             NaN            NaN   NaN  NaN
# 4      NaN             NaN            NaN   NaN  NaN
# ...    ...             ...            ...   ...  ...
# 18236  NaN             NaN            NaN   NaN  NaN
# 18237  NaN             NaN            NaN   NaN  NaN
# 18238  NaN             NaN            NaN   NaN  NaN
# 18239  NaN             NaN            NaN   NaN  NaN
# 18240  NaN             NaN            NaN   NaN  NaN
#
# [18241 rows x 5 columns]

# %%
ufo.dropna(how = 'any') # drop the row f any of the attribute has null value
# Out:
#                City Colors Reported Shape Reported State              Time
# 12           Belton             RED         SPHERE    SC   6/30/1939 20:00
# 19       Bering Sea             RED          OTHER    AK   4/30/1943 23:00
# 36       Portsmouth             RED      FORMATION    VA    7/10/1945 1:30
# 44        Blairsden           GREEN         SPHERE    CA   6/30/1946 19:00
# 82         San Jose            BLUE        CHEVRON    CA   7/15/1947 21:00
# ...             ...             ...            ...   ...               ...
# 18213      Pasadena           GREEN       FIREBALL    CA  12/28/2000 19:10
# 18216  Garden Grove          ORANGE          LIGHT    CA  12/29/2000 16:10
# 18220   Shasta Lake            BLUE           DISK    CA  12/29/2000 20:30
# 18233     Anchorage             RED        VARIOUS    AK  12/31/2000 21:00
# 18239   Eagle River             RED          LIGHT    WI  12/31/2000 23:45
#
# [2486 rows x 5 columns]

# %%
ufo.dropna(how = 'all')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.fillna(0).head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca               0       TRIANGLE    NY
# 1           Willingboro               0          OTHER    NJ
# 2               Holyoke               0           OVAL    CO
# 3               Abilene               0           DISK    KS
# 4  New York Worlds Fair               0          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
ufo.fillna({
    'City':'Abilene',
    'Colors Reported':'Black'
           }).head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca           Black       TRIANGLE    NY
# 1           Willingboro           Black          OTHER    NJ
# 2               Holyoke           Black           OVAL    CO
# 3               Abilene           Black           DISK    KS
# 4  New York Worlds Fair           Black          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
ufo.fillna(method = 'ffill').head(3)
# Out:
#           City Colors Reported Shape Reported State                Time
# 0       Ithaca             NaN       TRIANGLE    NY 1930-06-01 22:00:00
# 1  Willingboro             NaN          OTHER    NJ 1930-06-30 20:00:00
# 2      Holyoke             NaN           OVAL    CO 1931-02-15 14:00:00

# %%
ufo.fillna(method = 'bfill').head(3)
# Out:
#           City Colors Reported Shape Reported State                Time
# 0       Ithaca             RED       TRIANGLE    NY 1930-06-01 22:00:00
# 1  Willingboro             RED          OTHER    NJ 1930-06-30 20:00:00
# 2      Holyoke             RED           OVAL    CO 1931-02-15 14:00:00

# %%
ufo.fillna(method = 'bfill',limit = 1).head(3)
# Out:
#           City Colors Reported Shape Reported State                Time
# 0       Ithaca             NaN       TRIANGLE    NY 1930-06-01 22:00:00
# 1  Willingboro             NaN          OTHER    NJ 1930-06-30 20:00:00
# 2      Holyoke             NaN           OVAL    CO 1931-02-15 14:00:00

# %%
ufo.interpolate().head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
ufo.dropna(thresh = 1).head() # at lease one valid value
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %% [markdown]
# ### indexing in pandas/ grabbing rows and columns

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks[0:7] # these numbers only work for rows
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 3                          12.4         Europe
# 4                           5.9         Africa
# 5                           4.9  North America
# 6                           8.3  South America

# %%
drinks[['country','continent']] # these names work for column
# Out:
#          country      continent
# 0    Afghanistan           Asia
# 1        Albania         Europe
# 2        Algeria         Africa
# 3        Andorra         Europe
# 4         Angola         Africa
# ..           ...            ...
# 188    Venezuela  South America
# 189      Vietnam           Asia
# 190        Yemen           Asia
# 191       Zambia         Africa
# 192     Zimbabwe         Africa
#
# [193 rows x 2 columns]

# %%
drinks.iloc[0:7,2:4] # in iloc numbers work for both rows and columns
# Out:
#    spirit_servings  wine_servings
# 0                0              0
# 1              132             54
# 2                0             14
# 3              138            312
# 4               57             45
# 5              128             45
# 6               25            221

# %%
drinks.loc[0:6,['country','continent']]
# Out:
#              country      continent
# 0        Afghanistan           Asia
# 1            Albania         Europe
# 2            Algeria         Africa
# 3            Andorra         Europe
# 4             Angola         Africa
# 5  Antigua & Barbuda  North America
# 6          Argentina  South America

# %%
drinks.set_index(['country']).loc[['Afghanistan','Albania'],'beer_servings':'wine_servings']
# Out:
#              beer_servings  spirit_servings  wine_servings
# country
# Afghanistan              0                0              0
# Albania                 89              132             54

# %%
drinks.loc[drinks.country =='Argentina','wine_servings']
# Out:
# 6    221
# Name: wine_servings, dtype: int64

# %% [markdown]
# ### date time in pandas

# %%
ufo.head(3)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18216 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %%
ufo.Time.str.slice(-5,-3).astype(int).head()
# Out:
# 0    22
# 1    20
# 2    14
# 3    13
# 4    19
# Name: Time, dtype: int32

# %%
ufo['Time'] = pd.to_datetime(ufo.Time)

# %%
ufo.Time
# Out:
# 0       1930-06-01 22:00:00
# 1       1930-06-30 20:00:00
# 2       1931-02-15 14:00:00
# 3       1931-06-01 13:00:00
# 4       1933-04-18 19:00:00
#                 ...
# 18236   2000-12-31 23:00:00
# 18237   2000-12-31 23:00:00
# 18238   2000-12-31 23:45:00
# 18239   2000-12-31 23:45:00
# 18240   2000-12-31 23:59:00
# Name: Time, Length: 18241, dtype: datetime64[ns]

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18216 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 712.7+ KB

# %%
ufo.Time.dt.day_name()
# Out:
# 0         Sunday
# 1         Monday
# 2         Sunday
# 3         Monday
# 4        Tuesday
#           ...
# 18236     Sunday
# 18237     Sunday
# 18238     Sunday
# 18239     Sunday
# 18240     Sunday
# Name: Time, Length: 18241, dtype: object

# %%
(ufo.Time.max()-ufo.Time.min()).days
# Out:
# 25781

# %%
movie.head()
# Out:
#    user_id  age gender  occupation pincode
# 0        1   24      M  technician   85711
# 1        2   53      F       other   94043
# 2        3   23      M      writer   32067
# 3        4   24      M  technician   43537
# 4        5   33      F       other   15213

# %%
movie.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# Length: 943, dtype: bool

# %%
movie.pincode.duplicated().sum()
# Out:
# 148

# %% [markdown]
# ### map() ,apply(), applymap()

# %%
titanic = pd.read_csv('Titanictrain.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic['sex_num'] = titanic.Sex.map({'male':0,'female':1})

# %%
titanic['name_length'] = titanic.Name.apply(len)

# %%
titanic.loc[:,['Name','Sex','sex_num','name_length']]
# Out:
#                                                   Name     Sex  sex_num  \
# 0                              Braund, Mr. Owen Harris    male        0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female        1
# 2                               Heikkinen, Miss. Laina  female        1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female        1
# 4                             Allen, Mr. William Henry    male        0
# ..                                                 ...     ...      ...
# 886                              Montvila, Rev. Juozas    male        0
# 887                       Graham, Miss. Margaret Edith  female        1
# 888           Johnston, Miss. Catherine Helen "Carrie"  female        1
# 889                              Behr, Mr. Karl Howell    male        0
# 890                                Dooley, Mr. Patrick    male        0
#
#      name_length
# 0             23
# 1             51
# 2             22
# 3             44
# ...

# %%
titanic.Name.str.split(',').head()
# Out:
# 0                           [Braund,  Mr. Owen Harris]
# 1    [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                            [Heikkinen,  Miss. Laina]
# 3      [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                          [Allen,  Mr. William Henry]
# Name: Name, dtype: object

# %%
def get_element(mylist,position):
    return mylist[position]

# %%
titanic.Name.str.split(',').apply(get_element,position = 0)
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %%
titanic.Name.str.split(',').apply(lambda x:x[0]).head()
# Out:
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# Name: Name, dtype: object

# %%
drinks.head(3)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa

# %%
drinks.loc[:,'beer_servings':'wine_servings'].apply(max,axis = 0)
# Out:
# beer_servings      376
# spirit_servings    438
# wine_servings      370
# dtype: int64

# %% [raw]
# drinks.loc[:,'beer_servings':'wine_servings'].applymap(float)

# %% [markdown]
# ### Pivot_table

# %%
stock = pd.read_csv('http://bit.ly/smallstocks')
stock.head()
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT

# %%
stock.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
gp =stock.groupby(['Symbol','Date']).Close.mean()
gp
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
#         2016-10-04    113.00
#         2016-10-05    113.05
# CSCO    2016-10-03     31.50
#         2016-10-04     31.35
#         2016-10-05     31.59
# MSFT    2016-10-03     57.42
#         2016-10-04     57.24
#         2016-10-05     57.64
# Name: Close, dtype: float64

# %%
gp.index
# Out:
# MultiIndex([('AAPL', '2016-10-03'),
#             ('AAPL', '2016-10-04'),
#             ('AAPL', '2016-10-05'),
#             ('CSCO', '2016-10-03'),
#             ('CSCO', '2016-10-04'),
#             ('CSCO', '2016-10-05'),
#             ('MSFT', '2016-10-03'),
#             ('MSFT', '2016-10-04'),
#             ('MSFT', '2016-10-05')],
#            names=['Symbol', 'Date'])

# %%
gp.unstack()
# Out:
# Date    2016-10-03  2016-10-04  2016-10-05
# Symbol
# AAPL        112.52      113.00      113.05
# CSCO         31.50       31.35       31.59
# MSFT         57.42       57.24       57.64

# %%
stock.pivot_table(index ='Symbol',columns = 'Date',values = 'Close',aggfunc = 'mean',)
# Out:
# Date    2016-10-03  2016-10-04  2016-10-05
# Symbol
# AAPL        112.52      113.00      113.05
# CSCO         31.50       31.35       31.59
# MSFT         57.42       57.24       57.64

# %% [markdown]
# ### Merge

# %%
movie.head()
# Out:
#    user_id  age gender  occupation pincode
# 0        1   24      M  technician   85711
# 1        2   53      F       other   94043
# 2        3   23      M      writer   32067
# 3        4   24      M  technician   43537
# 4        5   33      F       other   15213
